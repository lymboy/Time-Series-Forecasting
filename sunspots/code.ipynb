# %%
# Load sunspot data
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('./dataset/monthly-sunspots.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#          Sunspots
# Month
# 1749-01      58.0
# 1749-02      62.6
# 1749-03      70.0
# 1749-04      55.7
# 1749-05      85.0
